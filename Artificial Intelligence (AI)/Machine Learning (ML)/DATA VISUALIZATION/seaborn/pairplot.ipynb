# %% [markdown]
# pairplot

# %%
import seaborn as sns
import pandas as pd

# Create a sample DataFrame
data = pd.DataFrame({
    'Length': [10, 20, 15, 25, 30],
    'Width': [5, 10, 8, 12, 15],
    'Weight': [50, 100, 75, 125, 150]
})

# Create the pairplot
sns.pairplot(data)
